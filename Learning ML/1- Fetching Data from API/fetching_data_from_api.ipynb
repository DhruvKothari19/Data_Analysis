# %%
import pandas as pd
# !pip install requests
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\kothari\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=4aedd2ae8f4cc2e9a045326bffc26095&language=en-US&page=1')

# %%
pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
# Out:
#         id                                   title  \
# 0      278                The Shawshank Redemption
# 1    19404             Dilwale Dulhania Le Jayenge
# 2      238                           The Godfather
# 3   533514            Violet Evergarden: The Movie
# 4   730154                          Your Eyes Tell
# 5      424                        Schindler's List
# 6   372754                Dou kyu sei – Classmates
# 7   724089               Gabriel's Inferno Part II
# 8      240                  The Godfather: Part II
# 9   696374                       Gabriel's Inferno
# 10  761053              Gabriel's Inferno Part III
# 11  372058                              Your Name.
# 12     129                           Spirited Away
# 13  496243                                Parasite
# 14  255709                                    Hope
# 15     389                            12 Angry Men
# 16     497                          The Green Mile
# ...

# %%
#creating an empty df
df = pd.DataFrame()

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=4aedd2ae8f4cc2e9a045326bffc26095&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df.append(temp_df,ignore_index=True)

# %%
#https://rapidapi.com/collection/list-of-free-apis

# %%
df2 = pd.read_csv('movies.csv')
df2.head()
# Out:
#    Unnamed: 0      id                         title  \
# 0           0     278      The Shawshank Redemption
# 1           1   19404   Dilwale Dulhania Le Jayenge
# 2           2     238                 The Godfather
# 3           3  533514  Violet Evergarden: The Movie
# 4           4  730154                Your Eyes Tell
#
#                                             overview release_date  popularity  \
# 0  Framed in the 1940s for the double murder of h...   1994-09-23      79.480
# 1  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20      30.856
# 2  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     104.510
# 3  As the world moves on from the war and technol...   2020-09-18      31.679
# 4  A tragic accident lead to Kaori's blindness, b...   2020-10-23      13.240
#
#    vote_average  vote_count
# 0           8.7       21011
# 1           8.7        3525
# 2           8.7       15697
# 3           8.7         203
# 4           8.7         272
